# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
def hinton(matrix, max_weight=None, ax=None,title='axis'):
    """Draw Hinton diagram for visualizing a weight matrix."""
    ax = ax if ax is not None else plt.gca()

    if not max_weight:
        max_weight = 2 ** np.ceil(np.log(np.abs(matrix).max()) / np.log(2))

    ax.patch.set_facecolor('gray')
    ax.set_aspect('equal', 'box')
    ax.xaxis.set_major_locator(plt.NullLocator())
    ax.yaxis.set_major_locator(plt.NullLocator())
    ax.set_title(title)
    for (x, y), w in np.ndenumerate(matrix):
        color = 'white' if w > 0 else 'black'
        size = np.sqrt(np.abs(w) / max_weight)
        rect = plt.Rectangle([x - size / 2, y - size / 2], size, size,
                             facecolor=color, edgecolor=color)
        ax.add_patch(rect)

    ax.autoscale_view()

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
figsize(20,10)
hinton(numpy.genfromtxt('./theta1_rev_amt.txt')[:-1])

# %%
y_pred = genfromtxt("y_pred_rev_share.txt")
y_act  = genfromtxt("y_act_rev_share.txt")

# %%
figsize(4,4)
scatter(y_pred,y_act, alpha=.1)
xlim(0,1)
# Out:
# (0, 1)

# %%
from sklearn.metrics import r2_score

r2_score(numpy.array([1,1,1]),[1,1,1])
# Out:
# 1.0

# %%
pd.DataFrame(numpy.genfromtxt('../../brand-fingerprint/theta1_rev_amt.txt')[:-1])
# Out:
#              0          1          2         3         4          5  \
# 0    -9.964454   6.258367  18.681833 -0.797388  2.793060  18.646702
# 1    12.591692   0.850877  14.217261 -8.033848 -2.707122 -13.628718
# 2     2.718690  -0.189481  18.452727  0.942591  2.675477   8.562598
# 3    13.104046   8.670762  11.399354  4.551718 -3.708834  -7.021642
# 4    -2.215973  12.907464  29.837722 -7.480954  1.655953 -10.000343
# 5    -0.689081   6.097354  10.321483  2.062974  4.449078   3.448017
# 6    -3.654453  18.944828  15.173977 -1.166658  6.670854   2.430078
# 7     1.334928  12.164363  10.710859 -3.569049 -1.327370   6.913895
# 8     3.194713  10.391367   8.830098  4.042694  0.715374   9.406505
# 9    -5.026174  12.128311  20.396516 -1.238150  7.117157  14.294688
# 10    3.977491   3.736491  17.031849 -3.981890 -1.900856   6.147132
# 11   -1.747390  18.105713   7.584341  0.745708  5.405164  -3.923298
# 12   -4.918863  15.948852  -6.533355  2.451450  5.713259  12.330077
# ...
